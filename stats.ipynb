# %%
import pandas as pd
contrib = pd.read_csv("financial_contributions.csv")

# %%
contrib
# Out:
#           Date                           Person  Sum  Px_num Currency  Clasa  \
# 0   23-05-2023  Nikolaje L Liuba Adriana Cuzman  250       1      RON  XII-X
# 1   15-04-2023                   Sebastian Ivan  500       2      RON  XII-D
# 2   18-04-2023                    Ciotescu Raul  200       1      RON  XII-D
# 3   18-04-2023          Danielescu Aura Codruta    2     450      RON  XII-E
# 4   05-05-2023                    Dragisa Uncul  425       2      RON  XII-E
# 5   12-05-2023       Moldovan Ioana Lucia Purge    1     200      RON  XII-X
# 6   15-05-2023                      Flavius Ban  200       1      RON  XII-D
# 7   19-05-2023                    Alina Petrica  200       1      RON  XII-D
# 8   19-05-2023                    Silviu Stance    2     400      RON  XII-X
# 9   20-05-2023               Florentin Munteanu    1     200      RON  XII-D
# 10  23-05-2023  Nikolaje L Liuba Adtiana Cuzman    1     150      RON  XII-X
# ...
