# %%
import pandas as pd
contrib = pd.read_csv("financial_contributions.csv")
contrib
contrib[['Date', 'Nume Prenume', 'Sursa', 'Currency', 'Incasat', 'NumPers','Clasa']]
# Out:
#           Date                              Nume Prenume    Sursa Currency  \
# 0   23-05-2023         Nikolaje L Liuba 4 Adriana Cuzman  Revolut      RON
# 1   15-04-2023                            Sebastian Ivan  Revolut      RON
# 2   18-04-2023                             Ciotescu Raul  Revolut      RON
# 3   18-04-2023                   Danielescu Aura Codruta  Revolut      RON
# 4   05-05-2023                             Dragisa Uncul  Revolut      RON
# 5   12-05-2023                Moldovan Ioana Lucia Purge  Revolut      RON
# 6   15-05-2023                               Flavius Ban  Revolut      RON
# 7   19-05-2023                             Alina Petrica  Revolut      RON
# 8   19-05-2023                             Silviu Stanca  Revolut      RON
# 9   20-05-2023                        Florentin Munteanu  Revolut      RON
# 10  23-05-2023         Nikolaje L Liuba 4 Adtiana Cuzman  Revolut      RON
# ...

# %%
cost_per_pers=120+30
colegi = contrib.NumPers.sum()
profesori = 10
total_px=colegi+profesori
incasat = contrib.Incasat.sum()
real_cost = total_px*cost_per_pers
spre_retur = incasat-real_cost

print(f'Persoane: {total_px} (inclusiv 10 profesori)')
print(f'RON incasat: {incasat}')
print(f'RON real_cost: {real_cost}')
print(f'RON retur: {spre_retur}')
# Out:
# Persoane: 66 (inclusiv 10 profesori)
# RON incasat: 11525
# RON real_cost: 9900
# RON retur: 1625

# %%
#todo
#1. flori scoala = 300 RON?
#2. apa scoala = 200 ron?
#3. share meniu info
#4. pay Vineri13
#5. org conf call via MS Teams
