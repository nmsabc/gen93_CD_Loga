# %%
import pandas as pd
contrib = pd.read_csv("financial_contributions.csv")
contrib
# Out:
#           Date                              Nume Prenume    Sursa Currency  \
# 0   23-05-2023         Nikolaje L Liuba 4 Adriana Cuzman  Revolut      RON
# 1   15-04-2023                            Sebastian Ivan  Revolut      RON
# 2   18-04-2023                             Ciotescu Raul  Revolut      RON
# 3   18-04-2023                   Danielescu Aura Codruta       BT      RON
# 4   05-05-2023                             Dragisa Uncul  Revolut      RON
# 5   12-05-2023                Moldovan Ioana Lucia Purge  Revolut      RON
# 6   15-05-2023                               Flavius Ban  Revolut      RON
# 7   19-05-2023                             Alina Petrica  Revolut      RON
# 8   19-05-2023                             Silviu Stanca  Revolut      RON
# 9   20-05-2023                        Florentin Munteanu  Revolut      RON
# 10  23-05-2023         Nikolaje L Liuba 4 Adtiana Cuzman  Revolut      RON
# ...

# %%
total_px = contrib.NumPers.sum()
incasat = contrib.Incasat.sum()
real_cost = (total_px+10)*70 
spre_retur = contrib.Retur.sum()-real_cost

print(f'Persoane: {total_px} si 10 profesori')
print(f'incasat: {incasat}')
print(f'real_cost: {real_cost}')
print(f'retur: {spre_retur}')
# Out:
# Persoane: 18 si 10 profesori
# incasat: 3825
# real_cost: 1960
# retur: -295
